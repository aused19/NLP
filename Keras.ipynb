# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
text = 'My name is Maria'

# %%
text.split()
# Out:
# ['My', 'name', 'is', 'Maria']

# %%
tokenizer.fit_on_texts(text.split())

# %%
sequences = tokenizer.texts_to_sequences(text.split())

# %%
sequences
# Out:
# [[1], [2], [3], [4]]

# %%
#Conocer el vocabulario del texto, para añadir en la capa embedding de nuestro modelo de keras
vocab_size = len(tokenizer.word_index)
# Out:
# {1: 'my', 2: 'name', 3: 'is', 4: 'maria'}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Instanciar un modelo Sequential
model = Sequential()

# Añadir una capa Dense con 50 neuronas y una entrada de 1 neurona
model.add(Dense(50, input_shape=(1,), activation='relu'))

# Añadir dos capas Dense más con 50 neuronas y activación relu
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))

# Terminar tu modelo con una capa Dense y sin activación para la salida
model.add(Dense(1))

# %%
#Compile
model.compile(optimizer='adam', loss='rmse')
#Train
model.fit(X_train,y_train ,epochs = 20,validation_data = (X_test, y_test) ,metrics = ['accuracy'])#Se deja fuera un porcentaje de datos de entrenamiento para realizar pruebas en cada época
#Predict with X_train
preds = model.predict(X_train)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# EARLY STOPPING

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
